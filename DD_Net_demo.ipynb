# %%
! pip install -q keras

# %%
import numpy as np
import math
import random
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import glob
from tqdm import tqdm
import pickle
import scipy.ndimage.interpolation as inter
from scipy.signal import medfilt 
from scipy.spatial.distance import cdist

from keras.optimizers import *
from keras.models import Model
from keras.layers import *
from keras.layers.core import *
from tensorflow.keras.callbacks import *
from keras.layers.convolutional import *
from keras import backend as K
import keras
import tensorflow as tf

import google.colab.files

# %% [markdown]
# 1. Define configurations

# %%
random.seed(1234)

class Config():
    def __init__(self):
        self.frame_l = 32 # the length of frames
        self.joint_n = 15 # the number of joints
        self.joint_d = 2 # the dimension of joints
        self.clc_num = 21 # the number of class
        self.feat_d = 105
        self.filters = 64
C = Config()

# %% [markdown]
# 2. Define data processing functions

# %%
# Temple resizing function
def zoom(p,target_l=64,joints_num=25,joints_dim=3):
    l = p.shape[0]
    p_new = np.empty([target_l,joints_num,joints_dim]) 
    for m in range(joints_num):
        for n in range(joints_dim):
            p[:,m,n] = medfilt(p[:,m,n],3)
            p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]         
    return p_new



# Calculate JCD feature
def norm_scale(x):
    return (x-np.mean(x))/np.mean(x)
  
def get_CG(p,C):
    M = []
    iu = np.triu_indices(C.joint_n,1,C.joint_n)
    for f in range(C.frame_l): 
        d_m = cdist(p[f],p[f],'euclidean')       
        d_m = d_m[iu] 
        M.append(d_m)
    M = np.stack(M) 
    M = norm_scale(M)
    return M
  
  
# Genrate dataset  
def data_generator(T,C,le):
    X_0 = []
    X_1 = []
    Y = []
    for i in tqdm(range(len(T['pose']))): 
        p = np.copy(T['pose'][i])
        p = zoom(p,target_l=C.frame_l,joints_num=C.joint_n,joints_dim=C.joint_d)

        label = np.zeros(C.clc_num)
        label[le.transform(T['label'])[i]-1] = 1   

        M = get_CG(p,C)

        X_0.append(M)
        X_1.append(p)
        Y.append(label)

    X_0 = np.stack(X_0)  
    X_1 = np.stack(X_1) 
    Y = np.stack(Y)
    return X_0,X_1,Y

# %% [markdown]
# 3. Define network

# %%
def poses_diff(x):
    H, W = x.get_shape()[1],x.get_shape()[2]
    x = tf.subtract(x[:,1:,...],x[:,:-1,...])
    x = tf.image.resize(x,size=[H,W]) 
    return x

def pose_motion(P,frame_l):
    P_diff_slow = Lambda(lambda x: poses_diff(x))(P)
    P_diff_slow = Reshape((frame_l,-1))(P_diff_slow)
    P_fast = Lambda(lambda x: x[:,::2,...])(P)
    P_diff_fast = Lambda(lambda x: poses_diff(x))(P_fast)
    P_diff_fast = Reshape((int(frame_l/2),-1))(P_diff_fast)
    return P_diff_slow,P_diff_fast
    
def c1D(x,filters,kernel):
    x = Conv1D(filters, kernel_size=kernel,padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def block(x,filters):
    x = c1D(x,filters,3)
    x = c1D(x,filters,3)
    return x
    
def d1D(x,filters):
    x = Dense(filters,use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def build_FM(frame_l=32,joint_n=22,joint_d=2,feat_d=231,filters=16):   
    M = Input(shape=(frame_l,feat_d))
    P = Input(shape=(frame_l,joint_n,joint_d))
    
    diff_slow,diff_fast = pose_motion(P,frame_l)
    
    x = c1D(M,filters*2,1)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,3)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,1)
    x = MaxPooling1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x_d_slow = c1D(diff_slow,filters*2,1)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,3)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,1)
    x_d_slow = MaxPool1D(2)(x_d_slow)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
        
    x_d_fast = c1D(diff_fast,filters*2,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,3) 
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,1) 
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
   
    x = concatenate([x,x_d_slow,x_d_fast])
    x = block(x,filters*2)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)
    
    x = block(x,filters*4)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*8)
    x = SpatialDropout1D(0.1)(x)
    
    return Model(inputs=[M,P],outputs=x)


def build_DD_Net(C):
    M = Input(name='M', shape=(C.frame_l,C.feat_d))  
    P = Input(name='P', shape=(C.frame_l,C.joint_n,C.joint_d)) 
    
    FM = build_FM(C.frame_l,C.joint_n,C.joint_d,C.feat_d,C.filters)
    
    x = FM([M,P])

    x = GlobalMaxPool1D()(x)
    
    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = Dense(C.clc_num, activation='softmax')(x)
    
    ######################Self-supervised part
    model = Model(inputs=[M,P],outputs=x)
    return model

# %%
DD_Net = build_DD_Net(C)
DD_Net.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  M (InputLayer)                 [(None, 32, 105)]    0           []
#
#  P (InputLayer)                 [(None, 32, 15, 2)]  0           []
#
#  model (Functional)             (None, 4, 512)       1714816     ['M[0][0]',
#                                                                   'P[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 512)         0           ['model[0][0]']
#  xPooling1D)
#
#  dense (Dense)                  (None, 128)          65536       ['global_max_pooling1d[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 128)         512         ['dense[0][0]']
#  ormalization)
#
#  leaky_re_lu_15 (LeakyReLU)     (None, 128)          0           ['batch_normalization_15[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['leaky_re_lu_15[0][0]']
#
#  dense_1 (Dense)                (None, 128)          16384       ['dropout[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 128)         512         ['dense_1[0][0]']
#  ormalization)
#
#  leaky_re_lu_16 (LeakyReLU)     (None, 128)          0           ['batch_normalization_16[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['leaky_re_lu_16[0][0]']
#
#  dense_2 (Dense)                (None, 21)           2709        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 1,800,469
# Trainable params: 1,794,837
# Non-trainable params: 5,632
# __________________________________________________________________________________________________

# %% [markdown]
# 4. Load dataset (download GT_train_1.pkl and  GT_test_1.pkl from github )

# %%
# !wget https://github.com/fandulu/DD-Net/archive/master.zip
# !unzip master.zip
# !rm master.zip
# Out:
# --2023-03-16 14:04:47--  https://github.com/fandulu/DD-Net/archive/master.zip
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/fandulu/DD-Net/zip/refs/heads/master [following]
# --2023-03-16 14:04:47--  https://codeload.github.com/fandulu/DD-Net/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.121.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.121.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [        <=>         ]  79.09M  8.98MB/s    in 9.4s
#
# 2023-03-16 14:04:56 (8.44 MB/s) - ‘master.zip’ saved [82934337]
#
# Archive:  master.zip
# f26a9994b0bafc41096fa269eab89c2757d71499
#    creating: DD-Net-master/
#   inflating: DD-Net-master/.gitignore
#    creating: DD-Net-master/JHMDB/
#   inflating: DD-Net-master/JHMDB/README.md
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_heavy.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_lite.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_middle.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_data_preprocessing.ipynb
#   inflating: DD-Net-master/JHMDB/utils.py
#    creating: DD-Net-master/JHMDB/weights/
#  extracting: DD-Net-master/JHMDB/weights/__init__.py
#   inflating: DD-Net-master/LICENSE
#   inflating: DD-Net-master/README.md
#    creating: DD-Net-master/SHREC/
#   inflating: DD-Net-master/SHREC/README.md
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_lite.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_data_preprocessing.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_lite.ipynb
#    creating: DD-Net-master/SHREC/images/
#   inflating: DD-Net-master/SHREC/images/SHREC_14.png
#   inflating: DD-Net-master/SHREC/images/SHREC_28.png
#   inflating: DD-Net-master/SHREC/utils.py
#    creating: DD-Net-master/SHREC/weights/
#  extracting: DD-Net-master/SHREC/weights/.gitkeep
#  extracting: DD-Net-master/SHREC/weights/__init__.py
#    creating: DD-Net-master/data/
#    creating: DD-Net-master/data/JHMDB/
#   inflating: DD-Net-master/data/JHMDB/GT_test_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_3.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_3.pkl
#   inflating: DD-Net-master/data/JHMDB/joint_positions.zip
#   inflating: DD-Net-master/data/JHMDB/splits.zip
#    creating: DD-Net-master/data/SHREC/
#  extracting: DD-Net-master/data/SHREC/__init__.py
#   inflating: DD-Net-master/data/SHREC/test.pickle
#   inflating: DD-Net-master/data/SHREC/test.pkl
#   inflating: DD-Net-master/data/SHREC/train.pickle
#   inflating: DD-Net-master/data/SHREC/train.pkl
#    creating: DD-Net-master/mics/
#  extracting: DD-Net-master/mics/__init__.py
#   inflating: DD-Net-master/mics/demo.png
#   inflating: DD-Net-master/mics/look.gif
#   inflating: DD-Net-master/mics/paper.png

# %% [markdown]
# # 新段落

# %%
Train = pickle.load(open("/content/DD-Net-master/data/JHMDB/GT_train_1.pkl", "rb"))
Test = pickle.load(open("/content/DD-Net-master/data/JHMDB/GT_test_1.pkl", "rb"))

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(Train['label'])

X_0,X_1,Y = data_generator(Train,C,le)
X_test_0,X_test_1,Y_test = data_generator(Test,C,le)
# Out:
#   0%|          | 0/433 [00:00<?, ?it/s]<ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#   6%|▌         | 24/433 [00:00<00:01, 239.78it/s]<ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  11%|█▏        | 49/433 [00:00<00:01, 241.10it/s]<ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  17%|█▋        | 75/433 [00:00<00:01, 248.31it/s]<ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  23%|██▎       | 100/433 [00:00<00:01, 241.91it/s]<ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  29%|██▉       | 126/433 [00:00<00:01, 243.86it/s]<ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  35%|███▍      | 151/433 [00:00<00:01, 242.71it/s]<ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  41%|████      | 176/433 [00:00<00:01, 220.60it/s]<ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  46%|████▌     | 199/433 [00:00<00:01, 222.38it/s]<ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# ...
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  61%|██████▏   | 108/176 [00:00<00:00, 139.75it/s]<ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  70%|██████▉   | 123/176 [00:00<00:00, 137.09it/s]<ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  78%|███████▊  | 138/176 [00:00<00:00, 140.06it/s]<ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  87%|████████▋ | 153/176 [00:01<00:00, 140.90it/s]<ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
#  95%|█████████▌| 168/176 [00:01<00:00, 139.58it/s]<ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# <ipython-input-4-69347f67161c>:8: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# 100%|██████████| 176/176 [00:01<00:00, 141.55it/s]

# %% [markdown]
# 5. Start train on split 1

# %%
lr = 1e-3
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1],Y,
                    batch_size=len(Y),
                    epochs=600,
                    verbose=True,
                    shuffle=True,
                    callbacks=[lrScheduler],
                    validation_data=([X_test_0,X_test_1],Y_test)      
                    )
lr = 1e-4
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5
600
# 1/1 [==============================] - 0s 73ms/step - loss: 0.1176 - accuracy: 0.9931 - val_loss: 3.4999 - val_accuracy: 0.2330 - lr: 5.0000e-04
# Epoch 81/600
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0981 - accuracy: 0.9908 - val_loss: 3.5079 - val_accuracy: 0.2216 - lr: 5.0000e-04
# Epoch 82/600
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1035 - accuracy: 0.9885 - val_loss: 3.5174 - val_accuracy: 0.2159 - lr: 5.0000e-04
# Epoch 83/600
# 1/1 [==============================] - 0s 73ms/step - loss: 0.1031 - accuracy: 0.9815 - val_loss: 3.5197 - val_accuracy: 0.2159 - lr: 5.0000e-04
# Epoch 84/600
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1020 - accuracy: 0.9931 - val_loss: 3.5438 - val_accuracy: 0.2159 - lr: 5.0000e-04
# Epoch 85/600
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0919 - accuracy: 0.9954 - val_loss: 3.5601 - val_accuracy: 0.2159 - lr: 5.0000e-04
# Epoch 86/600
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0932 - accuracy: 0.9931 - val_loss: 3.5710 - val_accuracy: 0.2159 - lr: 5.0000e-04
# Epoch 87/600
# 1/1 [==============================] - 0s 77ms/step - loss: 0.1142 - accuracy: 0.9931 - val_loss: 3.5749 - val_accuracy: 0.2273 - lr: 5.0000e-04
# Epoch 88/600
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1061 - accuracy: 0.9861 - val_loss: 3.5712 - val_accuracy: 0.2273 - lr: 5.0000e-04
# Epoch 89/600
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0787 - accuracy: 1.0000 - val_loss: 3.5781 - val_accuracy: 0.2273 - lr: 5.0000e-04
# Epoch 90/600
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0794 - accuracy: 0.9954 - val_loss: 3.5880 - val_accuracy: 0.2273 - lr: 5.0000e-04
# Epoch 91/600
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0905 - accuracy: 0.9908 - val_loss: 3.5836 - val_accuracy: 0.2273 - lr: 5.0000e-04
# Epoch 92/600
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0839 - accuracy: 0.9931 - val_loss: 3.5877 - val_accuracy: 0.2330 - lr: 5.0000e-04
# Epoch 93/600
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0872 - accuracy: 0.9977 - val_loss: 3.5871 - val_accuracy: 0.2386 - lr: 5.0000e-04
# Epoch 94/600
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1042 - accuracy: 0.9908 - val_loss: 3.5820 - val_accuracy: 0.2386 - lr: 5.0000e-04
# Epoch 95/600
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0954 - accuracy: 0.9908 - val_loss: 3.5842 - val_accuracy: 0.2443 - lr: 2.5000e-04
# Epoch 96/600
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0761 - accuracy: 0.9908 - val_loss: 3.5744 - val_accuracy: 0.2443 - lr: 2.5000e-04
# Epoch 97/600
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0794 - accuracy: 0.9954 - val_loss: 3.5695 - val_accuracy: 0.2443 - lr: 2.5000e-04
# Epoch 98/600
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0764 - accuracy: 0.9954 - val_loss: 3.5658 - val_accuracy: 0.2443 - lr: 2.5000e-04
# Epoch 99/600
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0789 - accuracy: 0.9954 - val_loss: 3.5657 - val_accuracy: 0.2443 - lr: 2.5000e-04
# Epoch 100/600
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0874 - accuracy: 0.9977 - val_loss: 3.5678 - val_accuracy: 0.2443 - lr: 2.5000e-04
# Epoch 101/600
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0830 - accuracy: 0.9931 - val_loss: 3.5698 - val_accuracy: 0.2443 - lr: 2.5000e-04
# Epoch 102/600
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0844 - accuracy: 0.9931 - val_loss: 3.5696 - val_accuracy: 0.2500 - lr: 2.5000e-04
# Epoch 103/600
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0653 - accuracy: 1.0000 - val_loss: 3.5702 - val_accuracy: 0.2500 - lr: 2.5000e-04
# Epoch 104/600
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0790 - accuracy: 0.9977 - val_loss: 3.5687 - val_accuracy: 0.2557 - lr: 2.5000e-04
# Epoch 105/600
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0698 - accuracy: 1.0000 - val_loss: 3.5688 - val_accuracy: 0.2557 - lr: 2.5000e-04
# Epoch 106/600
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0754 - accuracy: 0.9954 - val_loss: 3.5718 - val_accuracy: 0.2557 - lr: 2.5000e-04
# Epoch 107/600
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0830 - accuracy: 0.9931 - val_loss: 3.5699 - val_accuracy: 0.2557 - lr: 2.5000e-04
# Epoch 108/600
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0863 - accuracy: 0.9908 - val_loss: 3.5637 - val_accuracy: 0.2557 - lr: 2.5000e-04
# Epoch 109/600
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0708 - accuracy: 0.9954 - val_loss: 3.5610 - val_accuracy: 0.2557 - lr: 1.2500e-04
# Epoch 110/600
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0697 - accuracy: 0.9908 - val_loss: 3.5605 - val_accuracy: 0.2557 - lr: 1.2500e-04
# Epoch 111/600
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0679 - accuracy: 0.9977 - val_loss: 3.5603 - val_accuracy: 0.2557 - lr: 1.2500e-04
# Epoch 112/600
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0840 - accuracy: 0.9908 - val_loss: 3.5631 - val_accuracy: 0.2557 - lr: 1.2500e-04
# Epoch 113/600
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0858 - accuracy: 0.9931 - val_loss: 3.5616 - val_accuracy: 0.2557 - lr: 1.2500e-04
# Epoch 114/600
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0819 - accuracy: 0.9931 - val_loss: 3.5605 - val_accuracy: 0.2557 - lr: 1.2500e-04
# Epoch 115/600
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0780 - accuracy: 0.9931 - val_loss: 3.5630 - val_accuracy: 0.2614 - lr: 1.2500e-04
# Epoch 116/600
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0677 - accuracy: 1.0000 - val_loss: 3.5648 - val_accuracy: 0.2614 - lr: 1.2500e-04
# Epoch 117/600
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0876 - accuracy: 0.9954 - val_loss: 3.5691 - val_accuracy: 0.2614 - lr: 1.2500e-04
# Epoch 118/600
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0865 - accuracy: 0.9954 - val_loss: 3.5676 - val_accuracy: 0.2727 - lr: 6.2500e-05
# Epoch 119/600
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0797 - accuracy: 0.9931 - val_loss: 3.5661 - val_accuracy: 0.2727 - lr: 6.2500e-05
# Epoch 120/600
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0759 - accuracy: 0.9908 - val_loss: 3.5652 - val_accuracy: 0.2784 - lr: 6.2500e-05
# Epoch 121/600
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0747 - accuracy: 0.9954 - val_loss: 3.5644 - val_accuracy: 0.2784 - lr: 6.2500e-05
# Epoch 122/600
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0639 - accuracy: 0.9931 - val_loss: 3.5640 - val_accuracy: 0.2784 - lr: 6.2500e-05
# Epoch 123/600
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0691 - accuracy: 0.9954 - val_loss: 3.5626 - val_accuracy: 0.2898 - lr: 6.2500e-05
# Epoch 124/600
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0804 - accuracy: 0.9885 - val_loss: 3.5603 - val_accuracy: 0.2898 - lr: 6.2500e-05
# Epoch 125/600
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0776 - accuracy: 0.9977 - val_loss: 3.5602 - val_accuracy: 0.2898 - lr: 6.2500e-05
# Epoch 126/600
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0731 - accuracy: 0.9954 - val_loss: 3.5598 - val_accuracy: 0.2898 - lr: 6.2500e-05
# Epoch 127/600
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0701 - accuracy: 0.9954 - val_loss: 3.5589 - val_accuracy: 0.2898 - lr: 6.2500e-05
# Epoch 128/600
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0800 - accuracy: 0.9908 - val_loss: 3.5588 - val_accuracy: 0.2955 - lr: 3.1250e-05
# Epoch 129/600
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0760 - accuracy: 0.9977 - val_loss: 3.5586 - val_accuracy: 0.2955 - lr: 3.1250e-05
# Epoch 130/600
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0741 - accuracy: 0.9954 - val_loss: 3.5590 - val_accuracy: 0.2955 - lr: 3.1250e-05
# Epoch 131/600
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0900 - accuracy: 0.9908 - val_loss: 3.5578 - val_accuracy: 0.2955 - lr: 3.1250e-05
# Epoch 132/600
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0621 - accuracy: 1.0000 - val_loss: 3.5569 - val_accuracy: 0.2955 - lr: 3.1250e-05
# Epoch
600
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0638 - accuracy: 0.9977 - val_loss: 2.6544 - val_accuracy: 0.4261 - lr: 5.0000e-06
# Epoch 252/600
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0785 - accuracy: 0.9885 - val_loss: 2.6441 - val_accuracy: 0.4318 - lr: 5.0000e-06
# Epoch 253/600
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0642 - accuracy: 0.9977 - val_loss: 2.6343 - val_accuracy: 0.4318 - lr: 5.0000e-06
# Epoch 254/600
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0770 - accuracy: 1.0000 - val_loss: 2.6235 - val_accuracy: 0.4318 - lr: 5.0000e-06
# Epoch 255/600
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0764 - accuracy: 0.9977 - val_loss: 2.6126 - val_accuracy: 0.4318 - lr: 5.0000e-06
# Epoch 256/600
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0728 - accuracy: 0.9977 - val_loss: 2.6022 - val_accuracy: 0.4318 - lr: 5.0000e-06
# Epoch 257/600
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0653 - accuracy: 0.9977 - val_loss: 2.5920 - val_accuracy: 0.4318 - lr: 5.0000e-06
# Epoch 258/600
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0720 - accuracy: 1.0000 - val_loss: 2.5821 - val_accuracy: 0.4318 - lr: 5.0000e-06
# Epoch 259/600
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0629 - accuracy: 0.9977 - val_loss: 2.5714 - val_accuracy: 0.4318 - lr: 5.0000e-06
# Epoch 260/600
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0659 - accuracy: 1.0000 - val_loss: 2.5613 - val_accuracy: 0.4432 - lr: 5.0000e-06
# Epoch 261/600
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0587 - accuracy: 1.0000 - val_loss: 2.5511 - val_accuracy: 0.4432 - lr: 5.0000e-06
# Epoch 262/600
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0700 - accuracy: 1.0000 - val_loss: 2.5415 - val_accuracy: 0.4432 - lr: 5.0000e-06
# Epoch 263/600
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0648 - accuracy: 0.9977 - val_loss: 2.5314 - val_accuracy: 0.4432 - lr: 5.0000e-06
# Epoch 264/600
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0764 - accuracy: 1.0000 - val_loss: 2.5228 - val_accuracy: 0.4489 - lr: 5.0000e-06
# Epoch 265/600
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0757 - accuracy: 0.9977 - val_loss: 2.5128 - val_accuracy: 0.4489 - lr: 5.0000e-06
# Epoch 266/600
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0689 - accuracy: 0.9977 - val_loss: 2.5025 - val_accuracy: 0.4545 - lr: 5.0000e-06
# Epoch 267/600
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0682 - accuracy: 1.0000 - val_loss: 2.4927 - val_accuracy: 0.4545 - lr: 5.0000e-06
# Epoch 268/600
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0747 - accuracy: 0.9977 - val_loss: 2.4832 - val_accuracy: 0.4545 - lr: 5.0000e-06
# Epoch 269/600
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0760 - accuracy: 0.9977 - val_loss: 2.4728 - val_accuracy: 0.4602 - lr: 5.0000e-06
# Epoch 270/600
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0692 - accuracy: 0.9931 - val_loss: 2.4628 - val_accuracy: 0.4602 - lr: 5.0000e-06
# Epoch 271/600
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0754 - accuracy: 0.9977 - val_loss: 2.4529 - val_accuracy: 0.4659 - lr: 5.0000e-06
# Epoch 272/600
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0735 - accuracy: 0.9908 - val_loss: 2.4435 - val_accuracy: 0.4659 - lr: 5.0000e-06
# Epoch 273/600
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0647 - accuracy: 0.9954 - val_loss: 2.4341 - val_accuracy: 0.4659 - lr: 5.0000e-06
# Epoch 274/600
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0704 - accuracy: 0.9977 - val_loss: 2.4252 - val_accuracy: 0.4659 - lr: 5.0000e-06
# Epoch 275/600
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0697 - accuracy: 0.9977 - val_loss: 2.4155 - val_accuracy: 0.4659 - lr: 5.0000e-06
# Epoch 276/600
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0689 - accuracy: 0.9977 - val_loss: 2.4071 - val_accuracy: 0.4659 - lr: 5.0000e-06
# Epoch 277/600
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0777 - accuracy: 0.9931 - val_loss: 2.3977 - val_accuracy: 0.4659 - lr: 5.0000e-06
# Epoch 278/600
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0662 - accuracy: 0.9977 - val_loss: 2.3886 - val_accuracy: 0.4659 - lr: 5.0000e-06
# Epoch 279/600
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0801 - accuracy: 0.9954 - val_loss: 2.3788 - val_accuracy: 0.4659 - lr: 5.0000e-06
# Epoch 280/600
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0742 - accuracy: 0.9954 - val_loss: 2.3694 - val_accuracy: 0.4659 - lr: 5.0000e-06
# Epoch 281/600
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0821 - accuracy: 0.9931 - val_loss: 2.3603 - val_accuracy: 0.4659 - lr: 5.0000e-06
# Epoch 282/600
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0919 - accuracy: 0.9885 - val_loss: 2.3509 - val_accuracy: 0.4773 - lr: 5.0000e-06
# Epoch 283/600
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0719 - accuracy: 0.9931 - val_loss: 2.3412 - val_accuracy: 0.4886 - lr: 5.0000e-06
# Epoch 284/600
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0781 - accuracy: 0.9977 - val_loss: 2.3313 - val_accuracy: 0.5000 - lr: 5.0000e-06
# Epoch 285/600
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0682 - accuracy: 0.9977 - val_loss: 2.3212 - val_accuracy: 0.5000 - lr: 5.0000e-06
# Epoch 286/600
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0708 - accuracy: 0.9954 - val_loss: 2.3118 - val_accuracy: 0.5000 - lr: 5.0000e-06
# Epoch 287/600
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0759 - accuracy: 0.9954 - val_loss: 2.3030 - val_accuracy: 0.5000 - lr: 5.0000e-06
# Epoch 288/600
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0686 - accuracy: 0.9908 - val_loss: 2.2936 - val_accuracy: 0.5000 - lr: 5.0000e-06
# Epoch 289/600
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0617 - accuracy: 0.9977 - val_loss: 2.2846 - val_accuracy: 0.5000 - lr: 5.0000e-06
# Epoch 290/600
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0691 - accuracy: 0.9977 - val_loss: 2.2759 - val_accuracy: 0.5000 - lr: 5.0000e-06
# Epoch 291/600
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0729 - accuracy: 0.9908 - val_loss: 2.2676 - val_accuracy: 0.5000 - lr: 5.0000e-06
# Epoch 292/600
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0842 - accuracy: 0.9908 - val_loss: 2.2593 - val_accuracy: 0.5057 - lr: 5.0000e-06
# Epoch 293/600
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0872 - accuracy: 0.9908 - val_loss: 2.2508 - val_accuracy: 0.5057 - lr: 5.0000e-06
# Epoch 294/600
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0751 - accuracy: 0.9908 - val_loss: 2.2417 - val_accuracy: 0.5057 - lr: 5.0000e-06
# Epoch 295/600
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0739 - accuracy: 0.9977 - val_loss: 2.2336 - val_accuracy: 0.5057 - lr: 5.0000e-06
# Epoch 296/600
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0712 - accuracy: 0.9885 - val_loss: 2.2252 - val_accuracy: 0.5114 - lr: 5.0000e-06
# Epoch 297/600
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0694 - accuracy: 0.9977 - val_loss: 2.2171 - val_accuracy: 0.5114 - lr: 5.0000e-06
# Epoch 298/600
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0650 - accuracy: 1.0000 - val_loss: 2.2087 - val_accuracy: 0.5114 - lr: 5.0000e-06
# Epoch 299/600
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0702 - accuracy: 0.9954 - val_loss: 2.2007 - val_accuracy: 0.5114 - lr: 5.0000e-06
# Epoch 300/600
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0696 - accuracy: 0.9954 - val_loss: 2.1919 - val_accuracy: 0.5114 - lr: 5.0000e-06
# Epoch 301/600
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0587 - accuracy: 1.0000 - val_loss: 2.1834 - val_accuracy: 0.5114 - lr: 5.0000e-06
# Epoch 302/600
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0669 - accuracy: 0.9977 - val_loss: 2.1759 - val_accuracy: 0.5114 - lr: 5.0000e-06
# Epoch 303/600
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0711 - accuracy: 0.9931 - val_loss: 2.1683 - val_accuracy: 0.5170 - lr: 5.0000e-06
# Epoch 304/600
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0782 - accuracy: 0.9954 - val_loss: 2.1599 - val_accuracy: 0.5170 - lr: 5.0000e-06
# Epoch 305/600
# ...
# Epoch 501/600
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0477 - accuracy: 0.9977 - val_loss: 0.6193 - val_accuracy: 0.8409 - lr: 5.0000e-06
# Epoch 502/600
# 1/1 [==============================] - 0s 86ms/step - loss: 0.